# %% [markdown]
# ### Question 1:
# You all are pilots, you have to land a plane, the altitude required for landing a plane is 1000ft, if it
# is less than that tell the pilot to land the plane, or it is more than that but less than 5000ft ask the
# pilot to "come down to 1000ft", else if it is more than 5000ft ask the pilot to "go around and try
# later"

# %%
altitude = int(input('Enter the current altitude of plane :'))
altitude_req = 1000

if altitude > 5000:
    print('You should go around and try later...')
elif (altitude > 1000) and (altitude <= 5000):
    print('You should come down to',altitude_req,'ft')
elif altitude <= 1000:
    print('You are good to land the plane')
# Out:
# Enter the current altitude of plane :600
# You are good to land the plane
